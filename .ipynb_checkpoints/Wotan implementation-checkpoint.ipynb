# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from wotan import flatten

# %%
###'/data/jpr64/NG0535-0523_802_2017,2017S_CYCLE1807.fits'

def load_file(filename):
    """Loads the NGTS data file in my files and returns the hdu object"""
    hdu = fits.open(filename)
    return hdu

def load_obj(obj_index):
    """Loads the time series and flux for a given obj_index (not id) then removes points with 0 flux. """
    obj_index = int(obj_index)
    time = hdu['hjd'].data[obj_index]
    time = time / (24*60*60)
    
    flux = hdu['sysrem_flux3'].data[obj_index]
    flux[flux == 0] = np.nan
    
    flux_mean = hdu['catalogue'].data['flux_mean']
    flux_mean = flux_mean[obj_index]
    return time, flux, flux_mean

# %%
hdu = load_file('/data/jpr64/NG0535-0523_802_2017,2017S_CYCLE1807.fits')
time, flux, f_mean = load_obj(4129)

flux /= f_mean

# %%
###Looking at detrended LC

flatten_lc, trend_lc = flatten(
    time,                 # Array of time values
    flux,                 # Array of flux values
    method='supersmoother',
    window_length=0.5,    # The length of the filter window in units of ``time``
    break_tolerance=1,  # Split into segments at breaks longer than that
    return_trend=True,# Return trend and flattened light curve
    cval = 2


)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-48b16fc1dd87> in <module>()
#       8     break_tolerance=1,  # Split into segments at breaks longer than that
#       9     return_trend=True,# Return trend and flattened light curve
# ---> 10     cval = 2
#      11
#      12
#
# ~/.local/lib/python3.6/site-packages/wotan/flatten.py in flatten(time, flux, window_length, edge_cutoff, break_tolerance, cval, return_trend, method, kernel, kernel_size, kernel_period, proportiontocut, robust, max_splines, return_nsplines, mask, verbose)
#     262                 middle_span=constants.middle_span * win,
#     263                 final_span=constants.upper_span * win
# --> 264                 ).fit(time_view, flux_view,).predict(time_view)
#     265         elif method == 'cofiam':
#     266             trend_segment = detrend_cofiam(
#
# ~/.local/lib/python3.6/site-packages/supersmoother/smoother.py in fit(self, t, y, dy, presorted)
#      30         """
#      31         self.t, self.y, self.dy = self._validate_inputs(t, y, dy, presorted)
# ---> 32         self._fit(self.t, self.y, self.dy)
#      33         return self
#      34
#
# ~/.local/lib/python3.6/site-packages/supersmoother/supersmoother.py in _fit(self, t, y, dy)
#      60         ysmooth_primary = np.array([smoother.fit(t, y, dy, presorted=True)
#      61                                             .cv_values()
# ---> 62                                     for smoother in self.primary_smooths])
#      63         resids = abs((ysmooth_primary - y) / dy)
#      64
#
# ~/.local/lib/python3.6/site-packages/supersmoother/supersmoother.py in <listcomp>(.0)
#      60         ysmooth_primary = np.array([smoother.fit(t, y, dy, presorted=True)
#      61                                             .cv_values()
# ---> 62                                     for smoother in self.primary_smooths])
#      63         resids = abs((ysmooth_primary - y) / dy)
#      64
#
# ~/.local/lib/python3.6/site-packages/supersmoother/smoother.py in cv_values(self, cv)
#      51     def cv_values(self, cv=True):
#      52         """Return the values of the cross-validation for the fit data"""
# ---> 53         return self._cv_values(cv)
#      54
#      55     def cv_residuals(self, cv=True):
#
# ~/.local/lib/python3.6/site-packages/supersmoother/smoother.py in _cv_values(self, cv)
#     122     def _cv_values(self, cv=True):
#     123         return self._smoothfunc(self.t, self.y, self.dy, cv=cv,
# --> 124                                 span=self.span_int(), period=self.period)
#     125
#     126
#
# ~/.local/lib/python3.6/site-packages/supersmoother/utils.py in linear_smooth(t, y, dy, span, cv, t_out, span_out, period)
#     181
#     182     if np.any(denominator == 0):
# --> 183         raise ValueError("Zero denominator in linear smooth. This usually "
#     184                          "indicates that the input contains duplicate points.")
#     185
#
# ValueError: Zero denominator in linear smooth. This usually indicates that the input contains duplicate points.

# %%
plt.scatter(time, flatten_lc, s=1, color='black')
# plt.plot(time, trend_lc, linewidth=2, color='red')
plt.xlabel('Time (days)')
plt.ylabel('Raw flux')
plt.xlim(1400, 1450)
plt.ylim(0.9, 1.1);
plt.show();

# %%
flatten_lc1, trend_lc1 = flatten(time, flux, window_length=0.2, break_tolerance = 1, return_trend=True)
flatten_lc2, trend_lc2 = flatten(time, flux, window_length=0.5, break_tolerance = 1, return_trend=True)
flatten_lc3, trend_lc3 = flatten(time, flux, window_length=1, break_tolerance = 1,  return_trend=True)
plt.close()
plt.scatter(time, flux, s=1, color='black')
plt.plot(time, trend_lc1, linewidth=2, color='blue')  # overfit
plt.plot(time, trend_lc2, linewidth=2, color='red')  # about right
plt.plot(time, trend_lc3, linewidth=2, color='orange')  # underfit
plt.xlim(1400, 1450)
plt.ylim(0.9, 1.1)
plt.xlabel('Time (days)')
plt.ylabel('Raw flux')
plt.show();
