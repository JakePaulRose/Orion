# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import bin_tools
from wotan import flatten
import time
from OrionPY import OrionTools, Tools
from multiprocessing import Pool

# %%
data = np.load('/data/jpr64/rebinned_data_test.npy', allow_pickle = True)

# %%
lc = [x for x in data]

# %%
def calculate_mag(fluxes):
    return -2.5 * np.log10(fluxes) + 20.2

def calc_mean_and_rms(fluxes):
        magnitudes = calculate_mag(fluxes)
        mean_mag = np.nanmean(magnitudes)
        rms_mag = np.sqrt(np.mean(np.square(mean_mag - magnitudes)))
        return mean_mag, rms_mag

def mag_propogated_errors(fluxes, flux_errors):
    return 1.48 * (2.5/np.log(10))* (flux_errors/fluxes)/np.sqrt(27)

# %%
mean_mag_and_rms = [calc_mean_and_rms(x[:,1]) for x in lc]
x = np.array(mean_mag_and_rms)
mean_mags = x[:,0]
mean_rms = x[:,1]
# Out:
# /home/jpr64/.conda/envs/orion_jake/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log10
#
# /home/jpr64/.conda/envs/orion_jake/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: Mean of empty slice
#
# /home/jpr64/.conda/envs/orion_jake/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/jpr64/.conda/envs/orion_jake/lib/python3.7/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
flux = [x[:,1] for x in lc]
flux_error = [x[:,2] for x in lc]

# %%
flux_error_mag = np.array([np.nanmean(mag_propogated_errors(x,y)) for x,y in zip(flux, flux_error)])
# Out:
# /home/jpr64/.conda/envs/orion_jake/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: Mean of empty slice
#   """Entry point for launching an IPython kernel.

# %%
y = mean_rms/(flux_error_mag)

# %%
# %matplotlib notebook
plt.plot(mean_mags, y, linestyle = '', marker = 'o', markersize = 0.6)
plt.yscale('log')
plt.ylim(10**-2)
plt.xlabel(r'Mag')
plt.ylabel(r'Mean RMS / flux error (mag)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Mean RMS / flux error (mag)')

# %%
flux_error_mean = np.array([np.nanmean(x) for x in flux_error])
# Out:
# /home/jpr64/.conda/envs/orion_jake/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: Mean of empty slice
#   """Entry point for launching an IPython kernel.

# %%
flux_mean = np.array([np.nanmean(x) for x in flux])
# Out:
# /home/jpr64/.conda/envs/orion_jake/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: Mean of empty slice
#   """Entry point for launching an IPython kernel.

# %%
np.nanmean(flux_error_mean/flux_mean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-6089641bc1f0> in <module>
# ----> 1 np.nanmean(flux_error_mean/flux_mean)
#       2
#
# NameError: name 'flux_mean' is not defined

# %%
x = lc[12]
x[:,0][1] - x[:,0][0]
# Out:
# 0.004188161375850541
